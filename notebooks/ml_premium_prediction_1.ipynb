# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBRegressor
from sklearn.metrics import root_mean_squared_error,mean_squared_error

# %% [markdown]
# <h2 align="center" style="color:blue">Data Loading</h2>

# %%
df=pd.read_excel("../datasets/premiums.xlsx")
df.head()
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   18    Male  Northeast      Unmarried                     0   Overweight
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4        Regular     Self-Employed        > 40L            99
#
#        Medical History Insurance_Plan  Annual_Premium_Amount
# 0             Diabetes         Bronze                   9053
# ...

# %%
df.shape
# Out:
# (50000, 13)

# %%
df.columns=df.columns.str.replace(" ",'_').str.lower()
df.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   18    Male  Northeast      Unmarried                     0   Overweight
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4        Regular     Self-Employed        > 40L            99
#
#        medical_history insurance_plan  annual_premium_amount
# 0             Diabetes         Bronze                   9053
# ...

# %% [markdown]
# <h2 align="center" style="color:blue">Exploratory Data Analysis & Data Cleaning</h2>

# %% [markdown]
# ### Handle Missing Values

# %%
df.isna().sum()
# Out:
# age                       0
# gender                    0
# region                    0
# marital_status            0
# number_of_dependants      0
# bmi_category              0
# smoking_status           11
# employment_status         2
# income_level             13
# income_lakhs              0
# medical_history           0
# insurance_plan            0
# annual_premium_amount     0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           0
# employment_status        0
# income_level             0
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# dtype: int64

# %% [markdown]
# ### Handle Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  annual_premium_amount
# count  49976.000000          49976.000000  49976.000000           49976.000000
# mean      34.591764              1.711842     23.021150           15766.810189
# std       15.000378              1.498195     24.221794            8419.995271
# min       18.000000             -3.000000      1.000000            3501.000000
# 25%       22.000000              0.000000      7.000000            8607.750000
# 50%       31.000000              2.000000     17.000000           13928.000000
# 75%       45.000000              3.000000     31.000000           22273.500000
# max      356.000000              5.000000    930.000000           43471.000000

# %% [markdown]
# #### Data Cleaning: number_of_dependants

# %%
df[df['number_of_dependants']<0].shape
# Out:
# (72, 13)

# %%
df[df['number_of_dependants']<0]['number_of_dependants'].unique()
# Out:
# array([-3, -1], dtype=int64)

# %%
df['number_of_dependants']=abs(df['number_of_dependants'])

# %%
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  annual_premium_amount
# count  49976.000000          49976.000000  49976.000000           49976.000000
# mean      34.591764              1.717284     23.021150           15766.810189
# std       15.000378              1.491953     24.221794            8419.995271
# min       18.000000              0.000000      1.000000            3501.000000
# 25%       22.000000              0.000000      7.000000            8607.750000
# 50%       31.000000              2.000000     17.000000           13928.000000
# 75%       45.000000              3.000000     31.000000           22273.500000
# max      356.000000              5.000000    930.000000           43471.000000

# %% [markdown]
# ## 1. Numeric Columns

# %% [markdown]
# ### Univariate Analysis: Numeric Columns

# %% [markdown]
# #### Box plots for numeric columns

# %%
numeric_columns=df.select_dtypes(['float64','int64']).columns

# %%
for col in numeric_columns:
    sns.boxplot(x=df[col])
    plt.show()

# %% [markdown]
# ### Outlier Treatment: Age Column

# %%
df[df['age']>100].shape
# Out:
# (58, 13)

# %%
df[df['age']>100]['age'].unique()
# Out:
# array([224, 124, 136, 203, 356], dtype=int64)

# %%
df1=df[df['age']<=100]
print(df1.shape)
df1.head()
# Out:
# (49918, 13)
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   18    Male  Northeast      Unmarried                     0   Overweight
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4        Regular     Self-Employed        > 40L            99
#
#        medical_history insurance_plan  annual_premium_amount
# ...

# %%
df1.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  annual_premium_amount
# count  49918.000000          49918.000000  49918.000000           49918.000000
# mean      34.401839              1.717617     23.025141           15766.589286
# std       13.681600              1.492074     24.227912            8419.137327
# min       18.000000              0.000000      1.000000            3501.000000
# 25%       22.000000              0.000000      7.000000            8608.000000
# 50%       31.000000              2.000000     17.000000           13928.000000
# 75%       45.000000              3.000000     31.000000           22272.000000
# max       72.000000              5.000000    930.000000           43471.000000

# %% [markdown]
# ### Outlier Treatment: Income Column

# %%
def get_iqr_bounds(col):
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_bound=Q1-1.5*IQR
    upper_bound=Q3+1.5*IQR
    return lower_bound,upper_bound

# %%
lower_bound,upper_bound=get_iqr_bounds(df1['income_lakhs'])
lower_bound,upper_bound
# Out:
# (-29.0, 67.0)

# %%
df1[df1['income_lakhs']>upper_bound].shape
# Out:
# (3559, 13)

# %% [markdown]
# There are many legitimate records that we will get rid of if we use IQR bounds method. Hence after discussion with business we decided to use a simple quantile bound

# %%
quantile_threshold=df1['income_lakhs'].quantile(0.999)
quantile_threshold
# Out:
# 100.0

# %%
df1[df1['income_lakhs']>quantile_threshold].shape
# Out:
# (10, 13)

# %%
df2=df1[df1['income_lakhs']<=quantile_threshold].copy()
df2.shape
# Out:
# (49908, 13)

# %%
fig, axs = plt.subplots(nrows=2,ncols=2, figsize= (10,8))
axs=axs.flatten()
for ax, col in zip(axs,numeric_columns):
    sns.histplot(df2[col],ax=ax)
    ax.set_title(col)


plt.tight_layout()
plt.show()

# %%
df2.head(2)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 0     No Smoking          Salaried         <10L             6        Diabetes
# 1        Regular          Salaried         <10L             6        Diabetes
#
#   insurance_plan  annual_premium_amount
# 0         Bronze                   9053
# 1         Bronze                  16339

# %% [markdown]
# ### Bivariate Analysis: Numeric Columns

# %%
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'income_lakhs', 'annual_premium_amount'], dtype='object')

# %%
numeric_features = ['age', 'income_lakhs', 'number_of_dependants']
fig, axs = plt.subplots(nrows=1,ncols=len(numeric_features), figsize= (18,6))
axs=axs.flatten()

for ax, col in zip(axs,numeric_features):
    sns.scatterplot(data=df2,x=col,y='annual_premium_amount',ax=ax)
    ax.set_title(f'{col} vs. Annual Premium Amount')
    ax.set_xlabel(col)
    ax.set_ylabel('Annual Premium Amount')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Categorical Columns

# %%
catgorical_columns=df2.select_dtypes('object').columns
catgorical_columns
# Out:
# Index(['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status',
#        'employment_status', 'income_level', 'medical_history',
#        'insurance_plan'],
#       dtype='object')

# %%
for col in catgorical_columns:
    print(col,":",df2[col].unique())
# Out:
# gender : ['Male' 'Female']
# region : ['Northwest' 'Southeast' 'Northeast' 'Southwest']
# marital_status : ['Unmarried' 'Married']
# bmi_category : ['Normal' 'Obesity' 'Overweight' 'Underweight']
# smoking_status : ['No Smoking' 'Regular' 'Occasional' 'Smoking=0' 'Does Not Smoke'
#  'Not Smoking']
# employment_status : ['Salaried' 'Self-Employed' 'Freelancer']
# income_level : ['<10L' '10L - 25L' '> 40L' '25L - 40L']
# medical_history : ['Diabetes' 'High blood pressure' 'No Disease'
#  'Diabetes & High blood pressure' 'Thyroid' 'Heart disease'
#  'High blood pressure & Heart disease' 'Diabetes & Thyroid'
#  'Diabetes & Heart disease']
# insurance_plan : ['Bronze' 'Silver' 'Gold']

# %%
df2['smoking_status'].replace({
    'Smoking=0':'No Smoking',
    'Does Not Smoke':'No Smoking',
    'Not Smoking':'No Smoking'
},inplace=True)
# Out:
# C:\Users\Harsh\AppData\Local\Temp\ipykernel_6808\1981040169.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['smoking_status'].replace({

# %%
df2['smoking_status'].unique()
# Out:
# array(['No Smoking', 'Regular', 'Occasional'], dtype=object)

# %% [markdown]
# ### Univariate Analysis

# %%
df2['gender'].value_counts(normalize=True).index
# Out:
# Index(['Male', 'Female'], dtype='object', name='gender')

# %%
fig,axs=plt.subplots(nrows=3,ncols=3,figsize=(18,18))
axs=axs.flatten()
for ax,col in zip(axs,catgorical_columns):
    counts=df2[col].value_counts(normalize=True)*100
    sns.barplot(x=counts.index,y=counts.values,ax=ax)
    ax.set_title(f'Percentage Distribution of {col}')
    ax.set_ylabel('Percentage of Policyholders (%)')
    ax.set_xlabel(col)# Set xlabel to the column name for clarity

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
crosstab=pd.crosstab(df2['income_level'],df2['insurance_plan'])
print(crosstab)
crosstab.plot(kind='bar',stacked=True)
plt.title('Income vs Plan')
plt.ylabel('Count')
plt.show()
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L         5307  3880    5182
# 25L - 40L         3683  2840    3750
# <10L             12226   931    5486
# > 40L              329  3653    2641

# %%
sns.heatmap(crosstab,annot=True,cmap='coolwarm',fmt='d')
plt.title('Heatmap of Income vs Plan')
plt.show()

# %% [markdown]
# <h2 align="center" style="color:blue">Feature Engineering</h2>

# %%
df2.head(2)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 0     No Smoking          Salaried         <10L             6        Diabetes
# 1        Regular          Salaried         <10L             6        Diabetes
#
#   insurance_plan  annual_premium_amount
# 0         Bronze                   9053
# 1         Bronze                  16339

# %%
df2['medical_history'].unique()
# Out:
# array(['Diabetes', 'High blood pressure', 'No Disease',
#        'Diabetes & High blood pressure', 'Thyroid', 'Heart disease',
#        'High blood pressure & Heart disease', 'Diabetes & Thyroid',
#        'Diabetes & Heart disease'], dtype=object)

# %%
df2[['disease1','disease2']]=df2['medical_history'].str.split(" & ",expand=True)

# %%
df2.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   18    Male  Northeast      Unmarried                     0   Overweight
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4        Regular     Self-Employed        > 40L            99
#
#        medical_history insurance_plan  annual_premium_amount  \
# 0             Diabetes         Bronze                   9053
# ...

# %%
df2[['disease1','disease2']]=df2[['disease1','disease2']].apply(lambda x: x.str.lower())
df2 = df2.fillna({'disease1': 'none', 'disease2': 'none'})

# %%
df2.head(2)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 0     No Smoking          Salaried         <10L             6        Diabetes
# 1        Regular          Salaried         <10L             6        Diabetes
#
#   insurance_plan  annual_premium_amount  disease1 disease2
# 0         Bronze                   9053  diabetes     none
# 1         Bronze                  16339  diabetes     none

# %%
risk_scores={
    "diabetes": 6,
    "heart disease": 8,
    "high blood pressure":6,
    "thyroid": 5,
    "no disease": 0,
    "none":0
    
}
df2["total_risk_score"]=0
for disease in ['disease1', 'disease2']:
    df2["total_risk_score"]+=df2[disease].map(risk_scores)

# %%
max_score=df2['total_risk_score'].max()
min_score=df2['total_risk_score'].min()

df2['normalized_risk_score']=(df2['total_risk_score']-min_score)/(max_score-min_score)
df2.head(2)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 0     No Smoking          Salaried         <10L             6        Diabetes
# 1        Regular          Salaried         <10L             6        Diabetes
#
#   insurance_plan  annual_premium_amount  disease1 disease2  total_risk_score  \
# 0         Bronze                   9053  diabetes     none                 6
# 1         Bronze                  16339  diabetes     none                 6
#
#    normalized_risk_score
# 0               0.428571
# 1               0.428571

# %% [markdown]
# ### Encode Text Columns

# %%
df2['insurance_plan']=df2['insurance_plan'].map({'Bronze':1,'Silver':2,'Gold':3})

# %%
df2.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   18    Male  Northeast      Unmarried                     0   Overweight
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4        Regular     Self-Employed        > 40L            99
#
#        medical_history  insurance_plan  annual_premium_amount  \
# 0             Diabetes               1                   9053
# ...

# %%
df2.income_level.unique()
# Out:
# array(['<10L', '10L - 25L', '> 40L', '25L - 40L'], dtype=object)

# %%
df2['income_level']=df2['income_level'].map({'<10L':1,'10L - 25L':2,'25L - 40L':3,'> 40L':4})

# %%
nominal_cols = ['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status', 'employment_status']
df3=pd.get_dummies(data=df2,columns=nominal_cols,drop_first=True,dtype=int)
df3.head(3)
# Out:
#    age  number_of_dependants  income_level  income_lakhs      medical_history  \
# 0   26                     0             1             6             Diabetes
# 1   29                     2             1             6             Diabetes
# 2   49                     2             2            20  High blood pressure
#
#    insurance_plan  annual_premium_amount             disease1 disease2  \
# 0               1                   9053             diabetes     none
# 1               1                  16339             diabetes     none
# 2               2                  18164  high blood pressure     none
#
#    total_risk_score  ...  region_Southeast  region_Southwest  \
# 0                 6  ...                 0                 0
# 1                 6  ...                 1                 0
# 2                 6  ...                 0                 0
#
#    marital_status_Unmarried  bmi_category_Obesity  bmi_category_Overweight  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49908 entries, 0 to 49999
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              49908 non-null  int64
#  1   number_of_dependants             49908 non-null  int64
#  2   income_level                     49908 non-null  int64
#  3   income_lakhs                     49908 non-null  int64
#  4   medical_history                  49908 non-null  object
#  5   insurance_plan                   49908 non-null  int64
#  6   annual_premium_amount            49908 non-null  int64
#  7   disease1                         49908 non-null  object
#  8   disease2                         49908 non-null  object
#  9   total_risk_score                 49908 non-null  int64
#  10  normalized_risk_score            49908 non-null  float64
#  11  gender_Male                      49908 non-null  int32
# ...

# %%
df4=df3.drop(['medical_history','disease1','disease2','total_risk_score'],axis=1)

# %%
df4.head(2)
# Out:
#    age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 0   26                     0             1             6               1
# 1   29                     2             1             6               1
#
#    annual_premium_amount  normalized_risk_score  gender_Male  \
# 0                   9053               0.428571            1
# 1                  16339               0.428571            0
#
#    region_Northwest  region_Southeast  region_Southwest  \
# 0                 1                 0                 0
# 1                 0                 1                 0
#
#    marital_status_Unmarried  bmi_category_Obesity  bmi_category_Overweight  \
# 0                         1                     0                        0
# 1                         0                     1                        0
#
#    bmi_category_Underweight  smoking_status_Occasional  \
# 0                         0                          0
# ...

# %% [markdown]
# ### Calculate VIF for Multicolinearity

# %%
df4.columns
# Out:
# Index(['age', 'number_of_dependants', 'income_level', 'income_lakhs',
#        'insurance_plan', 'annual_premium_amount', 'normalized_risk_score',
#        'gender_Male', 'region_Northwest', 'region_Southeast',
#        'region_Southwest', 'marital_status_Unmarried', 'bmi_category_Obesity',
#        'bmi_category_Overweight', 'bmi_category_Underweight',
#        'smoking_status_Occasional', 'smoking_status_Regular',
#        'employment_status_Salaried', 'employment_status_Self-Employed'],
#       dtype='object')

# %%
cm=df4.corr()
plt.figure(figsize=(20,12))
sns.heatmap(cm,annot=True)
plt.xticks(rotation=45, ha='right')
#plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
X=df4.drop('annual_premium_amount',axis=1)
y=df4['annual_premium_amount']

cols_to_scale =['age', 'number_of_dependants', 'income_level', 'income_lakhs','insurance_plan']
scaler=MinMaxScaler()
X[cols_to_scale]=scaler.fit_transform(X[cols_to_scale])
X.head(3)
# Out:
#         age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 0  0.148148                   0.0      0.000000      0.050505             0.0
# 1  0.203704                   0.4      0.000000      0.050505             0.0
# 2  0.574074                   0.4      0.333333      0.191919             0.5
#
#    normalized_risk_score  gender_Male  region_Northwest  region_Southeast  \
# 0               0.428571            1                 1                 0
# 1               0.428571            0                 0                 1
# 2               0.428571            0                 0                 0
#
#    region_Southwest  marital_status_Unmarried  bmi_category_Obesity  \
# 0                 0                         1                     0
# 1                 0                         0                     1
# 2                 0                         0                     0
#
#    bmi_category_Overweight  bmi_category_Underweight  \
# ...

# %%
X.describe()
# Out:
#                 age  number_of_dependants  income_level  income_lakhs  \
# count  49908.000000          49908.000000  49908.000000  49908.000000
# mean       0.303733              0.343528      0.365900      0.221110
# std        0.253363              0.298406      0.349711      0.223946
# min        0.000000              0.000000      0.000000      0.000000
# 25%        0.074074              0.000000      0.000000      0.060606
# 50%        0.240741              0.400000      0.333333      0.161616
# 75%        0.500000              0.600000      0.666667      0.303030
# max        1.000000              1.000000      1.000000      1.000000
#
#        insurance_plan  normalized_risk_score   gender_Male  region_Northwest  \
# count    49908.000000           49908.000000  49908.000000       49908.00000
# mean         0.397401               0.291831      0.549631           0.20093
# std          0.392459               0.287420      0.497536           0.40070
# ...

# %%
def calculate_vif(data):
    vif_df=pd.DataFrame()
    vif_df['Columns']=data.columns
    vif_df['VIF']=[variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X)
# Out:
#                             Columns        VIF
# 0                               age   4.567634
# 1              number_of_dependants   4.534650
# 2                      income_level  12.450675
# 3                      income_lakhs  11.183367
# 4                    insurance_plan   3.584752
# 5             normalized_risk_score   2.687610
# 6                       gender_Male   2.421496
# 7                  region_Northwest   2.102556
# 8                  region_Southeast   2.922414
# 9                  region_Southwest   2.670666
# 10         marital_status_Unmarried   3.411185
# 11             bmi_category_Obesity   1.352806
# 12          bmi_category_Overweight   1.549922
# 13         bmi_category_Underweight   1.302886
# 14        smoking_status_Occasional   1.272745
# 15           smoking_status_Regular   1.777089
# 16       employment_status_Salaried   2.382134
# 17  employment_status_Self-Employed   2.137753

# %%
calculate_vif(X.drop('income_level',axis=1))
# Out:
#                             Columns       VIF
# 0                               age  4.545825
# 1              number_of_dependants  4.526598
# 2                      income_lakhs  2.480563
# 3                    insurance_plan  3.445682
# 4             normalized_risk_score  2.687326
# 5                       gender_Male  2.409980
# 6                  region_Northwest  2.100789
# 7                  region_Southeast  2.919775
# 8                  region_Southwest  2.668314
# 9          marital_status_Unmarried  3.393718
# 10             bmi_category_Obesity  1.352748
# 11          bmi_category_Overweight  1.549907
# 12         bmi_category_Underweight  1.302636
# 13        smoking_status_Occasional  1.272744
# 14           smoking_status_Regular  1.777024
# 15       employment_status_Salaried  2.374628
# 16  employment_status_Self-Employed  2.132810

# %%
X_reduced=X.drop('income_level',axis=1)
X_reduced.head()
# Out:
#         age  number_of_dependants  income_lakhs  insurance_plan  \
# 0  0.148148                   0.0      0.050505             0.0
# 1  0.203704                   0.4      0.050505             0.0
# 2  0.574074                   0.4      0.191919             0.5
# 3  0.222222                   0.6      0.767677             1.0
# 4  0.000000                   0.0      0.989899             0.5
#
#    normalized_risk_score  gender_Male  region_Northwest  region_Southeast  \
# 0               0.428571            1                 1                 0
# 1               0.428571            0                 0                 1
# 2               0.428571            0                 0                 0
# 3               0.000000            0                 0                 1
# 4               0.428571            1                 0                 0
#
#    region_Southwest  marital_status_Unmarried  bmi_category_Obesity  \
# ...

# %% [markdown]
# ### Model Training

# %%
X_train,X_test,y_train,y_test=train_test_split(X_reduced,y,test_size=0.30,random_state=10)

# shape of the X_train, X_test, y_train, y_test features
print("x train: ",X_train.shape)
print("x test: ",X_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# x train:  (34935, 17)
# x test:  (14973, 17)
# y train:  (34935,)
# y test:  (14973,)

# %% [markdown]
# ### Linear Regression

# %%
model_lr=LinearRegression()
model_lr.fit(X_train,y_train)

test_score=model_lr.score(X_test,y_test)
train_score=model_lr.score(X_train,y_train)
test_score, train_score
# Out:
# (0.9280547230217837, 0.9282143576916762)

# %%
y_pred = model_lr.predict(X_test)

mse_lr = mean_squared_error(y_test,y_pred)
rmse_lr = root_mean_squared_error(y_test,y_pred)
print("Linear Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# Linear Regression ==> MSE:  5165611.913027982 RMSE:  2272.798256121291

# %%
X_test.head(1)
# Out:
#            age  number_of_dependants  income_lakhs  insurance_plan  \
# 3598  0.481481                   0.4      0.343434             0.5
#
#       normalized_risk_score  gender_Male  region_Northwest  region_Southeast  \
# 3598               0.428571            1                 0                 1
#
#       region_Southwest  marital_status_Unmarried  bmi_category_Obesity  \
# 3598                 0                         1                     0
#
#       bmi_category_Overweight  bmi_category_Underweight  \
# 3598                        1                         0
#
#       smoking_status_Occasional  smoking_status_Regular  \
# 3598                          0                       1
#
#       employment_status_Salaried  employment_status_Self-Employed
# 3598                           1                                0

# %%
model_lr.intercept_
# Out:
# 4824.300272127104

# %%
model_lr.coef_
# Out:
# array([11160.92646188,  -676.44399066,  -514.22981577, 12557.01293645,
#         4810.35770228,   168.64666183,   -35.7192924 ,    39.96512973,
#          -24.65292857,  -935.76061134,  3387.91145477,  1599.36226775,
#          391.1713038 ,   735.91227798,  2234.8047119 ,   155.9846743 ,
#          415.90397305])

# %%
feature_importance = model_lr.coef_

coef_df = pd.DataFrame(feature_importance,index=X_train.columns,columns=['Coefficients'])

coef_df = coef_df.sort_values('Coefficients',ascending=True)

plt.figure(figsize=(8,4))
plt.barh(coef_df.index,coef_df['Coefficients'])
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Linear Regression')
plt.show()

# %% [markdown]
# ### Ridge Regression Model

# %%
model_rg=Ridge(alpha=1)
model_rg.fit(X_train,y_train)

test_score=model_rg.score(X_test,y_test)
train_score=model_rg.score(X_train,y_train)
test_score, train_score
# Out:
# (0.9280541644640345, 0.9282143198366275)

# %%
y_pred = model_rg.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)
print("Ridge Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# Ridge Regression ==> MSE:  5165652.017016523 RMSE:  2272.8070787060924

# %% [markdown]
# ### XGBoost

# %%
model_xgb = XGBRegressor(n_estimators=20, max_depth=3)
model_xgb.fit(X_train,y_train)

test_score=model_xgb.score(X_test,y_test)
train_score=model_xgb.score(X_train,y_train)
test_score, train_score
# Out:
# (0.9782300591468811, 0.978065013885498)

# %%
y_pred = model_xgb.predict(X_test)

mse_xgb = mean_squared_error(y_test, y_pred)
rmse_xgb = np.sqrt(mse_xgb)
print("Ridge Regression ==> MSE: ", mse_xgb, "RMSE: ", rmse_xgb)
# Out:
# Ridge Regression ==> MSE:  1563064.1356043513 RMSE:  1250.2256338774819

# %%
param_grid={
    'n_estimators': [20, 40, 50],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
}

random_search=RandomizedSearchCV(estimator=model_xgb,param_distributions=param_grid,n_iter=10,random_state=42,scoring='r2',cv=3,n_jobs=-1)
random_search.fit(X_train,y_train)
random_search.best_score_
# Out:
# 0.9809474547704061

# %%
random_search.best_params_
# Out:
# {'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.1}

# %%
best_model=random_search.best_estimator_

# %%
feature_importance = best_model.feature_importances_
coef_df = pd.DataFrame(feature_importance,index=X_train.columns,columns=['Coefficients'])

coef_df = coef_df.sort_values('Coefficients',ascending=True)

plt.figure(figsize=(8,4))
plt.barh(coef_df.index,coef_df['Coefficients'])
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Linear Regression')
plt.show()

# %% [markdown]
# ### Error Analysis

# %%
y_pred = best_model.predict(X_test)

residual = y_pred - y_test
residul_pct= (residual*100)/y_test

result_df = pd.DataFrame({
    "Actual" : y_test,
    "Predict" : y_pred,
    "Difference" : residual,
    "Difference_Pct" : residul_pct
})
result_df
# Out:
#        Actual       Predict   Difference  Difference_Pct
# 3598    20554  20334.953125  -219.046875       -1.065714
# 35794   29647  29378.779297  -268.220703       -0.904714
# 43608   20560  20618.185547    58.185547        0.283004
# 42730    5018   7352.829590  2334.829590       46.529087
# 18936    8929   8203.291992  -725.708008       -8.127540
# ...       ...           ...          ...             ...
# 5621    18848  18649.619141  -198.380859       -1.052530
# 6069     6956   6565.852051  -390.147949       -5.608797
# 21592    8332  10615.658203  2283.658203       27.408284
# 49274    5571   6820.886230  1249.886230       22.435581
# 27977    8922   6942.343750 -1979.656250      -22.188481
#
# [14973 rows x 4 columns]

# %%
sns.histplot(result_df['Difference_Pct'],kde=True)
plt.title('Distribution of Residuals')
plt.xlabel('Diff PCT')
plt.ylabel('Frequency')
plt.show()

# %%
extreme_error_threshold=10

extreme_result_df = result_df[np.abs(result_df['Difference_Pct'])>extreme_error_threshold]
extreme_result_df.head()
# Out:
#        Actual       Predict   Difference  Difference_Pct
# 42730    5018   7352.829590  2334.829590       46.529087
# 20029    5140   6670.849121  1530.849121       29.783057
# 4294     9631   7053.477539 -2577.522461      -26.762771
# 44419    4687   6670.849121  1983.849121       42.326629
# 6707     8826  10047.326172  1221.326172       13.837822

# %%
X_test.shape
# Out:
# (14973, 17)

# %%
extreme_result_df.shape
# Out:
# (4487, 4)

# %%
extreme_errors_pct=extreme_result_df.shape[0]/X_test.shape[0]
extreme_errors_pct
# Out:
# 0.29967274427302476

# %% [markdown]
# We have 30% extreme errors which means for 30% customers we will either overcharge or undercharge by 10% or more

# %%
extreme_result_df[np.abs(extreme_result_df['Difference_Pct'])>50].sort_values('Difference_Pct',ascending=False)
# Out:
#        Actual      Predict   Difference  Difference_Pct
# 36269    3501  6565.852051  3064.852051       87.542189
# 48801    3516  6565.852051  3049.852051       86.742095
# 42342    3521  6565.852051  3044.852051       86.476911
# 18564    3523  6565.852051  3042.852051       86.371049
# 7988     3527  6565.852051  3038.852051       86.159684
# ...       ...          ...          ...             ...
# 32671    4656  6994.980957  2338.980957       50.235845
# 14798    4371  6565.852051  2194.852051       50.213957
# 13736    4371  6565.852051  2194.852051       50.213957
# 10107    4710  7073.240723  2363.240723       50.174962
# 16908    4699  7053.477539  2354.477539       50.105928
#
# [549 rows x 4 columns]

# %% [markdown]
# There will be about 549 customers whom we will overcharge or underchage by more than 50%

# %%
X_test.index[1]
# Out:
# 35794

# %%
result_df.index[1]
# Out:
# 35794

# %% [markdown]
# We have only extreme error info not data like columns like  age ....etc and row have error so we have to find
# as we know X_test index and extreme result df index same so we can find the df by like this

# %%
extreme_error_df = X_test.loc[extreme_result_df.index]
extreme_error_df.head()
# Out:
#             age  number_of_dependants  income_lakhs  insurance_plan  \
# 42730  0.092593                   0.2      0.131313             0.0
# 20029  0.018519                   0.2      0.030303             0.0
# 4294   0.000000                   0.2      0.020202             0.0
# 44419  0.055556                   0.0      0.242424             0.0
# 6707   0.111111                   0.2      0.070707             0.5
#
#        normalized_risk_score  gender_Male  region_Northwest  region_Southeast  \
# 42730               0.428571            1                 0                 0
# 20029               0.000000            0                 1                 0
# 4294                0.000000            1                 0                 0
# 44419               0.000000            0                 0                 0
# 6707                0.000000            1                 0                 0
#
#        region_Southwest  marital_status_Unmarried  bmi_category_Obesity  \
# ...

# %%
for feature in X_test.columns:
    plt.figure(figsize=(10,4))
    sns.histplot(X_test[feature],kde=True,color='blue', label='Overall')
    sns.histplot(extreme_error_df[feature],kde=True,color='red', label='Extreme Errors')
    plt.legend()
    plt.title(f'Distribution of {feature} for Extreme Errors vs Overall')
    plt.show()

# %% [markdown]
# ### Reverse Scaling

# %%
cols_to_scale
# Out:
# ['age',
#  'number_of_dependants',
#  'income_level',
#  'income_lakhs',
#  'insurance_plan']

# %%
extreme_error_df.columns
# Out:
# Index(['age', 'number_of_dependants', 'income_lakhs', 'insurance_plan',
#        'normalized_risk_score', 'gender_Male', 'region_Northwest',
#        'region_Southeast', 'region_Southwest', 'marital_status_Unmarried',
#        'bmi_category_Obesity', 'bmi_category_Overweight',
#        'bmi_category_Underweight', 'smoking_status_Occasional',
#        'smoking_status_Regular', 'employment_status_Salaried',
#        'employment_status_Self-Employed'],
#       dtype='object')

# %%
extreme_error_df['income_level']=-1

# %%
reversed_df=pd.DataFrame()
reversed_df[cols_to_scale]=scaler.inverse_transform(extreme_error_df[cols_to_scale])

# %%
reversed_df.head()
# Out:
#     age  number_of_dependants  income_level  income_lakhs  insurance_plan
# 0  23.0                   1.0          -2.0          14.0             1.0
# 1  19.0                   1.0          -2.0           4.0             1.0
# 2  18.0                   1.0          -2.0           3.0             1.0
# 3  21.0                   0.0          -2.0          25.0             1.0
# 4  24.0                   1.0          -2.0           8.0             2.0

# %%
sns.histplot(reversed_df['age'])
plt.show()

# %% [markdown]
# This shows that majority of the extreme errors are coming from young age group (i.e. <25 years of age). We need to may be build a separate model for this segment
